# %% [markdown]
# <a href="https://colab.research.google.com/github/JN513/Curso-de-visaocomputacional-com-python/blob/master/Curso_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello world no google colab

# %%
print('ola')
# Out:
# ola

# %% [markdown]
# Abrindo e mostrando imagem com Open-CV

# %%
import cv2
from google.colab.patches import cv2_imshow

path = '/content/drive/My Drive/imagens/imgs/dog-5288071_1920.jpg'

imagem = cv2.imread(path)

cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1280 at 0x7FF6F43022E8>
